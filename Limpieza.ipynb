# %%
import pandas as pd
import numpy as np

# %%
filename= 'DATOS_CRUDOS.csv'
data= pd.read_csv(filename, index_col=0)
df=pd.DataFrame(data)
df.head()
# Out:
#                  DISTRITO  DEPARTAMENTO MUNICIPIO  \
# CODIGO
# 16-01-0137-46      16-006  ALTA VERAPAZ     COBAN
# 16-01-0138-46  16-01-0926  ALTA VERAPAZ     COBAN
# 16-01-0139-46  16-01-0927  ALTA VERAPAZ     COBAN
# 16-01-0140-46  16-01-0926  ALTA VERAPAZ     COBAN
# 16-01-0141-46  16-01-0924  ALTA VERAPAZ     COBAN
#
#                                             ESTABLECIMIENTO  \
# CODIGO
# 16-01-0137-46  INSTITUTO MIXTO NOCTURNO FRANCISCO MARROQUIN
# 16-01-0138-46                                 COLEGIO COBAN
# 16-01-0139-46              COLEGIO PARTICULAR MIXTO VERAPAZ
# 16-01-0140-46                       COLEGIO "LA INMACULADA"
# 16-01-0141-46      ESCUELA NACIONAL DE CIENCIAS COMERCIALES
#
#                                             DIRECCION  TELEFONO  \
# CODIGO
# 16-01-0137-46                 6A. AVENIDA 1-15 ZONA 4       NaN
# 16-01-0138-46  KM.2 SALIDA A SAN JUAN CHAMELCO ZONA 8  77945104
# 16-01-0139-46            KM 209.5 ENTRADA A LA CIUDAD  58015763
# ...

# %% [markdown]
# Análsis de las variables

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9728 entries, 16-01-0137-46 to nan
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DISTRITO         9405 non-null   str
#  1   DEPARTAMENTO     9706 non-null   str
#  2   MUNICIPIO        9706 non-null   str
#  3   ESTABLECIMIENTO  9703 non-null   str
#  4   DIRECCION        9637 non-null   str
#  5   TELEFONO         9024 non-null   str
#  6   SUPERVISOR       9402 non-null   str
#  7   DIRECTOR         8510 non-null   str
#  8   NIVEL            9706 non-null   str
#  9   SECTOR           9706 non-null   str
#  10  AREA             9706 non-null   str
#  11  STATUS           9706 non-null   str
#  12  MODALIDAD        9706 non-null   str
#  13  JORNADA          9706 non-null   str
#  14  PLAN             9706 non-null   str
#  15  DEPARTAMENTAL    9706 non-null   str
# dtypes: str(16)
# memory usage: 1.3+ MB

# %% [markdown]
# Se observa que todas las variables son cadenas. Son aproximadamente 16 variables. No todas son indispensables.

# %%
for col in df.select_dtypes(include=['int64', 'float64']).columns:
   moda, conteo = mode(df[col])
   print(f'La moda de {col} es {moda}')
